# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/Prime%20Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a Prime number.")
            break
    else:
        print(num, "is a Prime number.")
else:
    print(num, "is not a Prime number.")
# Out:
# Enter a number: 45
# 45 is not a Prime number.

# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/occurrences%20of%20a%20character.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Python Programming"
char = 'n'

count = 0
for c in text:
    if c == char:
        count += 1
print("Occurrences of", char, ":", count)
# Out:
# Occurrences of n : 2

# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/i)%20Length%20of%20sting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = input("Enter a string: ")
str2 = input("Enter another string: ")

#i. Length
print("Length of string:", len(str1))

#ii. Reversal
rev = str1[::-1]
print("Reversed string:", rev)

# iii. Equality check
if str1 == str2:
    print("Strings are equal")
else:
    print("Strings are not equal")

#iv. Palindrome check
if str1 == rev:
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")

#v. Substring check
substr = input("Enter a substring to check: ")
if substr in str1:
    print(substr, "is a substring of", str1)
else:
    print(substr, "is NOT a substring of", str1)
# Out:
# Enter a string: madam
# Enter another string: Madam
# Length of string: 5
# Reversed string: madam
# Strings are not equal
# The string is a palindrome
# Enter a substring to check: dam
# dam is a substring of madam

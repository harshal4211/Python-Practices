# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/Even%20Odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(num, "is an Even number.")
else:
    print(num, "is an Odd number.")
# Out:
# Enter a number: 4
# 4 is an Even number.

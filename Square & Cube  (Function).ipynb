# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/Square%20%26%20Cube%20%20(Function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def square_cube(n):
    square = n ** 2
    cube = n ** 3
    return square, cube

num = int(input("Enter a number: "))

s, c = square_cube(num)

print("Square =", s)
print("Cube =", c)
# Out:
# Enter a number: 44
# Square = 1936
# Cube = 85184

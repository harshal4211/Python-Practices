# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal4211/Python-Practices/blob/main/Split%20Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = """Python is easy.
It is powerful.
Used in many fields."""
lines = text.split('\n')
print("Splitted Lines:")
for line in lines:
    print(line)

for i in range(7):
    print(i)
# Out:
# Splitted Lines:
# Python is easy.
# It is powerful.
# Used in many fields.
# 0
# 1
# 2
# 3
# 4
# 5
# 6
